# %%
import pandas as pd
import statsapi

# %%
statsapi.lookup_player('alex gonzales')
# Out:
# []

# %%
player_list = pd.read_csv('playerid_list.csv', encoding='latin-1')

# %%
player_df = pd.DataFrame(player_list)[['LASTNAME','FIRSTNAME','MLBCODE']].dropna()
player_df.head()
# Out:
#   LASTNAME FIRSTNAME   MLBCODE
# 0   Ausmus      Brad  110385.0
# 1  Bagwell      Jeff  110432.0
# 2  Berkman     Lance  204020.0
# 3   Biggio     Craig  110987.0
# 4     Blum     Geoff  150398.0

# %%
altuve = pd.read_html('https://baseballsavant.mlb.com/savant-player/jose-altuve-514888')

# %%
altuve[2]
# Out:
#    Unnamed: 0     Season   Tm   LG     G    PA    AB    R     H   2B  ...    \
# 0         NaN       2011  HOU   NL    57   234   221   26    61   10  ...
# 1         NaN       2012  HOU   NL   147   630   576   80   167   34  ...
# 2         NaN       2013  HOU   AL   152   672   626   64   177   31  ...
# 3         NaN       2014  HOU   AL   158   707   660   85   225   47  ...
# 4         NaN       2015  HOU   AL   154   689   638   86   200   40  ...
# 5         NaN       2016  HOU   AL   161   717   640  108   216   42  ...
# 6         NaN       2017  HOU   AL   153   662   590  112   204   39  ...
# 7         NaN       2018  HOU   AL   137   599   534   84   169   29  ...
# 8         NaN       2019  HOU   AL   124   548   500   89   149   27  ...
# 9         NaN  9 Seasons  NaN  NaN  1243  5458  4985  734  1568  299  ...
#
#    RBI   BB   SO   SB  CS  HBP    AVG    OBP    SLG    OPS
# 0   12    5   29    7   3    2  0.276  0.297  0.357  0.654
# ...
